# %%
import numpy as np
import pandas as pd

# %%
# %pip install -r requirements.txt


# Version 11
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Version 12
