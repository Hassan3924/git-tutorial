# %%
import numpy as np
import pandas as pd

# %%
# %pip install -r requirements.txt
# Out:
# ...
#   Using cached aiohappyeyeballs-2.4.4-py3-none-any.whl.metadata (6.1 kB)
# ...
#   Using cached aiohttp-3.10.11-cp310-cp310-win_amd64.whl.metadata (8.0 kB)
# ...
#   Using cached aiosignal-1.3.1-py3-none-any.whl.metadata (4.0 kB)
# ...
#   Using cached alembic-1.14.0-py3-none-any.whl.metadata (7.4 kB)
# ...
#   Using cached annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# ...
#   Using cached anyio-4.6.2.post1-py3-none-any.whl.metadata (4.7 kB)
# ...
#   Using cached apache_airflow-2.10.3-py3-none-any.whl.metadata (44 kB)
# ...
#   Using cached apache_airflow_providers_common_compat-1.2.2-py3-none-any.whl.metadata (6.1 kB)
# ...
#   Using cached apache_airflow_providers_common_io-1.4.2-py3-none-any.whl.metadata (6.1 kB)
# ...
#   Using cached apache_airflow_providers_common_sql-1.20.0-py3-none-any.whl.metadata (6.2 kB)
# ...
#   Using cached apache_airflow_providers_fab-1.5.1-py3-none-any.whl.metadata (6.6 kB)
# ...
#   Using cached apache_airflow_providers_ftp-3.11.1-py3-none-any.whl.metadata (6.1 kB)
# ...

# %%
# Version 2
